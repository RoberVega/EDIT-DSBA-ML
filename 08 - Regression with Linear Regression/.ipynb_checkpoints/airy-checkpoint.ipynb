# %%
from scipy.special import airy
from cxroots import Circle

# %%
from numpy import exp, cos, sin
f = lambda z: (exp(2*z)*cos(z)-1-sin(z)+z**5)*(z*(z+2))**2

from cxroots import Circle
C = Circle(0,3)
roots = C.roots(f)
roots.show()

# %%
print(roots)
airy(2)[0]
# Out:
#  Multiplicity |               Root
# ------------------------------------------------
#       2       | -2.000000000000 -0.000000000000i
#       1       | -0.651114070264 -0.390425719088i
#       1       | -0.651114070264 +0.390425719088i
#       3       | -0.000000000000 -0.000000000000i
#       1       |  0.648578080954 -1.356622683988i
#       1       |  0.648578080954 +1.356622683988i
#       1       |  2.237557782467 +0.000000000000i
# 0.03492413042327436

# %%
from cxroots import Rectangle
rect = Rectangle([-30,0], [-1.2,1.2])
rect.show()

f= lambda z: z*airy(z)[0]**2-airy(z)[1]**2

roots = rect.roots(f)
roots.show()

# %%
print(roots)
# Out:
#  Multiplicity |               Root
# ------------------------------------------------
#       1       | -29.500413764413 +0.658773069470i
#       1       | -29.500413764413 -0.658773069470i
#       1       | -28.919143002576 -0.662585869354i
#       1       | -28.919143002576 +0.662585869354i
#       1       | -28.331970767405 +0.666526886792i
#       1       | -28.331970767405 -0.666526886792i
#       1       | -27.738649821983 -0.670604418447i
#       1       | -27.738649821983 +0.670604418447i
#       1       | -27.138914210922 +0.674827575146i
#       1       | -27.138914210922 -0.674827575146i
#       1       | -26.532477167345 +0.679206390927i
#       1       | -26.532477167345 -0.679206390927i
#       1       | -25.919028704962 -0.683751950868i
#       1       | -25.919028704962 +0.683751950868i
#       1       | -25.298232834822 +0.688476541706i
#       1       | -25.298232834822 -0.688476541706i
#       1       | -24.669724332012 -0.693393830299i
# ...

# %%
ordered_roots = np.sort(np.real(roots.roots))

# %%
import numpy as np
for i in range(len(ordered_roots)-2):
    print(ordered_roots[i+2]-ordered_roots[i])
# Out:
# 0.5812707618366737
# 0.5812707618366701
# 0.587172235171014
# 0.5871722351710176
# 0.5933209454224375
# 0.5933209454224482
# 0.5997356110606589
# 0.5997356110606553
# 0.6064370435766442
# 0.6064370435766513
# 0.6134484623827419
# 0.6134484623827312
# 0.6207958701408494
# 0.6207958701408565
# 0.6285085028100923
# 0.6285085028100816
# 0.6366193727669192
# 0.6366193727669263
# 0.645165928791446
# 0.6451659287914424
# 0.6541908640479264
# 0.6541908640479228
# 0.6637431132213365
# 0.6637431132213365
# 0.6738790938408812
# 0.6738790938408812
# 0.6846642662658304
# 0.6846642662658304
# 0.6961751144578869
# 0.6961751144578834
# 0.7085016896141028
# 0.7085016896141063
# 0.7217509174519172
# 0.7217509174519208
# 0.7360509579150047
# 0.7360509579149976
# 0.7515570406762322
# 0.7515570406762393
# 0.7684594106597444
# 0.7684594106597373
# 0.7869943568407844
# 0.7869943568407862
# 0.8074598591199784
# 0.8074598591199766
# 0.8302383499574528
# 0.8302383499574546
# 0.8558308000343064
# ...
